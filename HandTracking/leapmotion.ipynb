# %% [markdown]
# ## Using this file to connect to LeapMotion

# %% [markdown]
# # 1. Imports and Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic Model
mp_drawing = mp.solutions.drawing_utils # Drawing Utilities

# %%
def mediapipe_detection(image, model):
     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Color conversion from BGR -> RGB
     image.flags.writeable = False                  # Image is no longer writable
     results = model.process(image)                 # Make Prediction
     image.flags.writeable = True                   # Image is now writable
     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # Color conversion from RGB -> BGR
     return image, results


def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections


def draw_styled_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
# Stores all the keypoint values in an array
# Error checking if the hand isn't there, it'll insert a zero array
def extract_keypoints(results):
     lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
     rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
     return np.concatenate([lh, rh])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('New_Data') 

# Actions that we try to detect
actions = np.array(['a', 'b', 'c'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 20

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training & Testing

# %%
cap = cv2.VideoCapture(0)

# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
     
     # Loop through actions
     for action in actions:
          
          # Loop through sequences (videos)
          for sequence in range(no_sequences):
               
               # Loop through video length (sequence length)
               for frame_num in range(sequence_length):

                    # Read Feed
                    ret, frame = cap.read()
                    
                    # Made detections
                    image, results = mediapipe_detection(frame, holistic)
                     
                    # Draw landmarks
                    draw_styled_landmarks(frame, results)
                    
                    # NEW Apply wait logic
                    if frame_num == 0: 
                         cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                         cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                         # Show to screen
                         cv2.imshow('OpenCV Feed', image)
                         cv2.waitKey(1000)
                    else: 
                         cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                         # Show to screen
                         cv2.imshow('OpenCV Feed', image)
                    
                    # NEW Export keypoints
                    keypoints = extract_keypoints(results)
                    npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                    np.save(npy_path, keypoints)
                
                    # Show to screen
                    cv2.imshow('OpenCV Feed', frame)
                    
                    # Breaking gracefully
                    if cv2.waitKey(5) & 0xFF == ord('q'):
                         break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Lables and Features

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

sequences, labels = [], []
# Loop through actions
for action in actions:
     # Go through each number number in actions
     for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
         
          window = []
          # Grab all 30 frames and append them to window
          for frame_num in range(sequence_length):
               res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
               window.append(res)
          
          sequences.append(window)
          labels.append(label_map[action])
          
# Example: for hello, thank you, and i love you
     # You should have 90x30x1662
          # 30 for each one making 90
          # Each of the 90 have 30 np arrays
          # Each np array has 126 values

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('New Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()

# %%
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(20,126)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# To use LSTM in sequence, you need to set return_sequences to True. If the following is not LSTM, return False

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 4s 57ms/step - loss: 1.1009 - categorical_accuracy: 0.3529
# Epoch 2/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.0922 - categorical_accuracy: 0.3529
# Epoch 3/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0883 - categorical_accuracy: 0.3529
# Epoch 4/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.0767 - categorical_accuracy: 0.3765
# Epoch 5/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0640 - categorical_accuracy: 0.3882
# Epoch 6/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0484 - categorical_accuracy: 0.3882
# Epoch 7/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0156 - categorical_accuracy: 0.4706
# Epoch 8/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.9573 - categorical_accuracy: 0.5765
# Epoch 9/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.8745 - categorical_accuracy: 0.5059
# Epoch 10/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.8587 - categorical_accuracy: 0.5647
# Epoch 11/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.8303 - categorical_accuracy: 0.6824
# Epoch 12/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.7551 - categorical_accuracy: 0.6471
# Epoch 13/1000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.6494 - categorical_accuracy: 0.8235
# Epoch 14/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.7861 - categorical_accuracy: 0.6235
# Epoch 15/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.6254 - categorical_accuracy: 0.7882
# Epoch 16/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.6559 - categorical_accuracy: 0.6941
# Epoch 17/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.5873 - categorical_accuracy: 0.6824
# Epoch 18/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.5638 - categorical_accuracy: 0.6824
# Epoch 19/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.8693 - categorical_accuracy: 0.6706
# Epoch 20/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.6064 - categorical_accuracy: 0.7059
# Epoch 21/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.5930 - categorical_accuracy: 0.8353
# Epoch 22/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.5783 - categorical_accuracy: 0.8353
# Epoch 23/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.5918 - categorical_accuracy: 0.7647
# Epoch 24/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.5231 - categorical_accuracy: 0.7765
# Epoch 25/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.4658 - categorical_accuracy: 0.7882
# Epoch 26/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.5585 - categorical_accuracy: 0.7176
# Epoch 27/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.5224 - categorical_accuracy: 0.7412
# Epoch 28/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.4300 - categorical_accuracy: 0.7412
# Epoch 29/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.5519 - categorical_accuracy: 0.7647
# Epoch 30/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.4893 - categorical_accuracy: 0.7176
# Epoch 31/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.3773 - categorical_accuracy: 0.8824
# Epoch 32/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.4037 - categorical_accuracy: 0.8941
# Epoch 33/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.3581 - categorical_accuracy: 0.8706
# Epoch 34/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.3047 - categorical_accuracy: 0.8824
# Epoch 35/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2847 - categorical_accuracy: 0.8824
# Epoch 36/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2940 - categorical_accuracy: 0.8824
# Epoch 37/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2167 - categorical_accuracy: 0.9176
# Epoch 38/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1930 - categorical_accuracy: 0.9294
# Epoch 39/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1706 - categorical_accuracy: 0.9412
# Epoch 40/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1551 - categorical_accuracy: 0.9412
# Epoch 41/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1603 - categorical_accuracy: 0.9412
# Epoch 42/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1112 - categorical_accuracy: 0.9529
# Epoch 43/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0847 - categorical_accuracy: 0.9529
# Epoch 44/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0936 - categorical_accuracy: 0.9529
# Epoch 45/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.4585 - categorical_accuracy: 0.8824
# Epoch 46/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1676 - categorical_accuracy: 0.9412
# Epoch 47/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2404 - categorical_accuracy: 0.9176
# Epoch 48/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1296 - categorical_accuracy: 0.9294
# Epoch 49/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2188 - categorical_accuracy: 0.8824
# Epoch 50/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2257 - categorical_accuracy: 0.9412
# Epoch 51/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0955 - categorical_accuracy: 0.9647
# Epoch 52/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1564 - categorical_accuracy: 0.9412
# Epoch 53/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0792 - categorical_accuracy: 0.9647
# Epoch 54/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0506 - categorical_accuracy: 0.9882
# Epoch 55/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0441 - categorical_accuracy: 0.9882
# Epoch 56/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0389 - categorical_accuracy: 0.9882
# Epoch 57/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0285 - categorical_accuracy: 1.0000
# Epoch 58/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0137 - categorical_accuracy: 1.0000
# Epoch 59/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0848 - categorical_accuracy: 0.9882
# Epoch 60/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0646 - categorical_accuracy: 0.9647
# Epoch 61/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0494 - categorical_accuracy: 0.9882
# Epoch 62/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0131 - categorical_accuracy: 1.0000
# Epoch 63/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0180 - categorical_accuracy: 0.9882
# Epoch 64/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0455 - categorical_accuracy: 0.9882
# Epoch 65/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.5450 - categorical_accuracy: 0.7882
# Epoch 66/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1356 - categorical_accuracy: 0.7412
# Epoch 67/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.3676 - categorical_accuracy: 0.8824
# Epoch 68/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.5181 - categorical_accuracy: 0.9059
# Epoch 69/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.5409 - categorical_accuracy: 0.8941
# Epoch 70/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5018 - categorical_accuracy: 0.9059
# Epoch 71/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.4447 - categorical_accuracy: 0.8000
# Epoch 72/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.3903 - categorical_accuracy: 0.7294
# Epoch 73/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.6542 - categorical_accuracy: 0.8353
# Epoch 74/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.4757 - categorical_accuracy: 0.8706
# Epoch 75/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.3380 - categorical_accuracy: 0.9765
# Epoch 76/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2947 - categorical_accuracy: 0.9176
# Epoch 77/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.2304 - categorical_accuracy: 0.9294
# Epoch 78/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3239 - categorical_accuracy: 0.8353
# Epoch 79/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2597 - categorical_accuracy: 0.8588
# Epoch 80/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1815 - categorical_accuracy: 0.9647
# Epoch 81/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0978 - categorical_accuracy: 0.9882
# Epoch 82/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2646 - categorical_accuracy: 0.8824
# Epoch 83/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5733 - categorical_accuracy: 0.8353
# Epoch 84/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.2288 - categorical_accuracy: 0.9176
# Epoch 85/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3297 - categorical_accuracy: 0.8588
# Epoch 86/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2399 - categorical_accuracy: 0.8824
# Epoch 87/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2300 - categorical_accuracy: 0.9647
# Epoch 88/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.2110 - categorical_accuracy: 0.9529
# Epoch 89/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1624 - categorical_accuracy: 0.9412
# Epoch 90/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1063 - categorical_accuracy: 0.9882
# Epoch 91/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0923 - categorical_accuracy: 0.9765
# Epoch 92/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0746 - categorical_accuracy: 0.9882
# Epoch 93/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0432 - categorical_accuracy: 0.9882
# Epoch 94/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0351 - categorical_accuracy: 0.9882
# Epoch 95/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0183 - categorical_accuracy: 0.9882
# Epoch 96/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0174 - categorical_accuracy: 0.9882
# Epoch 97/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0047 - categorical_accuracy: 1.0000
# Epoch 98/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 99/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 100/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 101/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 6.2170e-04 - categorical_accuracy: 1.0000
# Epoch 102/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 4.1113e-04 - categorical_accuracy: 1.0000
# Epoch 103/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 2.8204e-04 - categorical_accuracy: 1.0000
# Epoch 104/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 9.9478e-05 - categorical_accuracy: 1.0000
# Epoch 105/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 3.1933e-05 - categorical_accuracy: 1.0000
# Epoch 106/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.2525e-05 - categorical_accuracy: 1.0000
# Epoch 107/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 4.9148e-06 - categorical_accuracy: 1.0000
# Epoch 108/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 3.7824 - categorical_accuracy: 0.9294
# Epoch 109/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.2787 - categorical_accuracy: 0.8824
# Epoch 110/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.3412 - categorical_accuracy: 0.8235
# Epoch 111/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.4143 - categorical_accuracy: 0.8235
# Epoch 112/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.4690 - categorical_accuracy: 0.8000
# Epoch 113/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.4779 - categorical_accuracy: 0.8000
# Epoch 114/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.3971 - categorical_accuracy: 0.8353
# Epoch 115/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.3751 - categorical_accuracy: 0.8706
# Epoch 116/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.3282 - categorical_accuracy: 0.9059
# Epoch 117/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2766 - categorical_accuracy: 0.9176
# Epoch 118/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2352 - categorical_accuracy: 0.9059
# Epoch 119/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1964 - categorical_accuracy: 0.8941
# Epoch 120/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1544 - categorical_accuracy: 0.9412
# Epoch 121/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1469 - categorical_accuracy: 0.9529
# Epoch 122/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1016 - categorical_accuracy: 0.9882
# Epoch 123/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1508 - categorical_accuracy: 0.9294
# Epoch 124/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.2252 - categorical_accuracy: 0.9412
# Epoch 125/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1122 - categorical_accuracy: 0.9765
# Epoch 126/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1873 - categorical_accuracy: 0.9647
# Epoch 127/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1321 - categorical_accuracy: 0.9647
# Epoch 128/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1123 - categorical_accuracy: 0.9765
# Epoch 129/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0686 - categorical_accuracy: 1.0000
# Epoch 130/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0477 - categorical_accuracy: 1.0000
# Epoch 131/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0397 - categorical_accuracy: 1.0000
# Epoch 132/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0288 - categorical_accuracy: 1.0000
# Epoch 133/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0106 - categorical_accuracy: 1.0000
# Epoch 134/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1016 - categorical_accuracy: 0.9882
# Epoch 135/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1187 - categorical_accuracy: 0.9647
# Epoch 136/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0109 - categorical_accuracy: 1.0000
# Epoch 137/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0309 - categorical_accuracy: 1.0000
# Epoch 138/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0249 - categorical_accuracy: 1.0000
# Epoch 139/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0237 - categorical_accuracy: 1.0000
# Epoch 140/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0254 - categorical_accuracy: 1.0000
# Epoch 141/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0199 - categorical_accuracy: 1.0000
# Epoch 142/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0153 - categorical_accuracy: 1.0000
# Epoch 143/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0127 - categorical_accuracy: 1.0000
# Epoch 144/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0108 - categorical_accuracy: 1.0000
# Epoch 145/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0072 - categorical_accuracy: 1.0000
# Epoch 146/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0058 - categorical_accuracy: 1.0000
# Epoch 147/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0053 - categorical_accuracy: 1.0000
# Epoch 148/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 149/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 150/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 151/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 152/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 153/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 8.5720e-04 - categorical_accuracy: 1.0000
# Epoch 154/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 6.9463e-04 - categorical_accuracy: 1.0000
# Epoch 155/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 5.6102e-04 - categorical_accuracy: 1.0000
# Epoch 156/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 4.9074e-04 - categorical_accuracy: 1.0000
# Epoch 157/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 4.2922e-04 - categorical_accuracy: 1.0000
# Epoch 158/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 3.6883e-04 - categorical_accuracy: 1.0000
# Epoch 159/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 3.1479e-04 - categorical_accuracy: 1.0000
# Epoch 160/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 2.6596e-04 - categorical_accuracy: 1.0000
# Epoch 161/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.3086e-04 - categorical_accuracy: 1.0000
# Epoch 162/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 2.0840e-04 - categorical_accuracy: 1.0000
# Epoch 163/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.8714e-04 - categorical_accuracy: 1.0000
# Epoch 164/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 1.7216e-04 - categorical_accuracy: 1.0000
# Epoch 165/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.5690e-04 - categorical_accuracy: 1.0000
# Epoch 166/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4469e-04 - categorical_accuracy: 1.0000
# Epoch 167/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.3007e-04 - categorical_accuracy: 1.0000
# Epoch 168/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.2127e-04 - categorical_accuracy: 1.0000
# Epoch 169/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.1020e-04 - categorical_accuracy: 1.0000
# Epoch 170/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.0402e-04 - categorical_accuracy: 1.0000
# Epoch 171/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 9.4368e-05 - categorical_accuracy: 1.0000
# Epoch 172/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.7636e-05 - categorical_accuracy: 1.0000
# Epoch 173/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 8.1664e-05 - categorical_accuracy: 1.0000
# Epoch 174/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 7.6861e-05 - categorical_accuracy: 1.0000
# Epoch 175/1000
# 3/3 [==============================] - 0s 85ms/step - loss: 7.1612e-05 - categorical_accuracy: 1.0000
# Epoch 176/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 6.7220e-05 - categorical_accuracy: 1.0000
# Epoch 177/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 6.2468e-05 - categorical_accuracy: 1.0000
# Epoch 178/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 5.9157e-05 - categorical_accuracy: 1.0000
# Epoch 179/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 5.5453e-05 - categorical_accuracy: 1.0000
# Epoch 180/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 5.2465e-05 - categorical_accuracy: 1.0000
# Epoch 181/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 4.9745e-05 - categorical_accuracy: 1.0000
# Epoch 182/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 4.6938e-05 - categorical_accuracy: 1.0000
# Epoch 183/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 4.4661e-05 - categorical_accuracy: 1.0000
# Epoch 184/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 4.2074e-05 - categorical_accuracy: 1.0000
# Epoch 185/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 3.9774e-05 - categorical_accuracy: 1.0000
# Epoch 186/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 3.8381e-05 - categorical_accuracy: 1.0000
# Epoch 187/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 3.6422e-05 - categorical_accuracy: 1.0000
# Epoch 188/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 3.4493e-05 - categorical_accuracy: 1.0000
# Epoch 189/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 3.3392e-05 - categorical_accuracy: 1.0000
# Epoch 190/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 3.1569e-05 - categorical_accuracy: 1.0000
# Epoch 191/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 3.0350e-05 - categorical_accuracy: 1.0000
# Epoch 192/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 2.8976e-05 - categorical_accuracy: 1.0000
# Epoch 193/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.7740e-05 - categorical_accuracy: 1.0000
# Epoch 194/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 2.6494e-05 - categorical_accuracy: 1.0000
# Epoch 195/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 2.5556e-05 - categorical_accuracy: 1.0000
# Epoch 196/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 2.4555e-05 - categorical_accuracy: 1.0000
# Epoch 197/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 2.3635e-05 - categorical_accuracy: 1.0000
# Epoch 198/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 2.2727e-05 - categorical_accuracy: 1.0000
# Epoch 199/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.1836e-05 - categorical_accuracy: 1.0000
# Epoch 200/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 2.1071e-05 - categorical_accuracy: 1.0000
# Epoch 201/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 2.0272e-05 - categorical_accuracy: 1.0000
# Epoch 202/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 1.9293e-05 - categorical_accuracy: 1.0000
# Epoch 203/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.8965e-05 - categorical_accuracy: 1.0000
# Epoch 204/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.8120e-05 - categorical_accuracy: 1.0000
# Epoch 205/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.7500e-05 - categorical_accuracy: 1.0000
# Epoch 206/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.6829e-05 - categorical_accuracy: 1.0000
# Epoch 207/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.6363e-05 - categorical_accuracy: 1.0000
# Epoch 208/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.5691e-05 - categorical_accuracy: 1.0000
# Epoch 209/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 1.5248e-05 - categorical_accuracy: 1.0000
# Epoch 210/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.4727e-05 - categorical_accuracy: 1.0000
# Epoch 211/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.4195e-05 - categorical_accuracy: 1.0000
# Epoch 212/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.3831e-05 - categorical_accuracy: 1.0000
# Epoch 213/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.3400e-05 - categorical_accuracy: 1.0000
# Epoch 214/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.2926e-05 - categorical_accuracy: 1.0000
# Epoch 215/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.2601e-05 - categorical_accuracy: 1.0000
# Epoch 216/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.2173e-05 - categorical_accuracy: 1.0000
# Epoch 217/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.1920e-05 - categorical_accuracy: 1.0000
# Epoch 218/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.1528e-05 - categorical_accuracy: 1.0000
# Epoch 219/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 1.1144e-05 - categorical_accuracy: 1.0000
# Epoch 220/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.0861e-05 - categorical_accuracy: 1.0000
# Epoch 221/1000
# 3/3 [==============================] - 0s 107ms/step - loss: 1.0527e-05 - categorical_accuracy: 1.0000
# Epoch 222/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 1.0245e-05 - categorical_accuracy: 1.0000
# Epoch 223/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 9.8977e-06 - categorical_accuracy: 1.0000
# Epoch 224/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 9.6706e-06 - categorical_accuracy: 1.0000
# Epoch 225/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 9.4041e-06 - categorical_accuracy: 1.0000
# Epoch 226/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 9.1966e-06 - categorical_accuracy: 1.0000
# Epoch 227/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.9218e-06 - categorical_accuracy: 1.0000
# Epoch 228/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 8.7465e-06 - categorical_accuracy: 1.0000
# Epoch 229/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 8.4366e-06 - categorical_accuracy: 1.0000
# Epoch 230/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.2164e-06 - categorical_accuracy: 1.0000
# Epoch 231/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.0075e-06 - categorical_accuracy: 1.0000
# Epoch 232/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 7.8308e-06 - categorical_accuracy: 1.0000
# Epoch 233/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 7.5868e-06 - categorical_accuracy: 1.0000
# Epoch 234/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 7.4185e-06 - categorical_accuracy: 1.0000
# Epoch 235/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 7.2432e-06 - categorical_accuracy: 1.0000
# Epoch 236/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 7.0385e-06 - categorical_accuracy: 1.0000
# Epoch 237/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 6.8436e-06 - categorical_accuracy: 1.0000
# Epoch 238/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 6.7076e-06 - categorical_accuracy: 1.0000
# Epoch 239/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 6.5281e-06 - categorical_accuracy: 1.0000
# Epoch 240/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 6.3514e-06 - categorical_accuracy: 1.0000
# Epoch 241/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 6.2027e-06 - categorical_accuracy: 1.0000
# Epoch 242/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 6.0485e-06 - categorical_accuracy: 1.0000
# Epoch 243/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 5.8704e-06 - categorical_accuracy: 1.0000
# Epoch 244/1000
# 3/3 [==============================] - 0s 79ms/step - loss: 5.7316e-06 - categorical_accuracy: 1.0000
# Epoch 245/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 5.5240e-06 - categorical_accuracy: 1.0000
# Epoch 246/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 5.4034e-06 - categorical_accuracy: 1.0000
# Epoch 247/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 5.2211e-06 - categorical_accuracy: 1.0000
# Epoch 248/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 5.0627e-06 - categorical_accuracy: 1.0000
# Epoch 249/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 4.8747e-06 - categorical_accuracy: 1.0000
# Epoch 250/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 4.7471e-06 - categorical_accuracy: 1.0000
# Epoch 251/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 4.6083e-06 - categorical_accuracy: 1.0000
# Epoch 252/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 4.4148e-06 - categorical_accuracy: 1.0000
# Epoch 253/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 4.2381e-06 - categorical_accuracy: 1.0000
# Epoch 254/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 4.1259e-06 - categorical_accuracy: 1.0000
# Epoch 255/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 3.9590e-06 - categorical_accuracy: 1.0000
# Epoch 256/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 3.7991e-06 - categorical_accuracy: 1.0000
# Epoch 257/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 3.6645e-06 - categorical_accuracy: 1.0000
# Epoch 258/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 3.4822e-06 - categorical_accuracy: 1.0000
# Epoch 259/1000
# 3/3 [==============================] - 0s 102ms/step - loss: 3.3335e-06 - categorical_accuracy: 1.0000
# Epoch 260/1000
# 3/3 [==============================] - 0s 83ms/step - loss: 3.2298e-06 - categorical_accuracy: 1.0000
# Epoch 261/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 3.0671e-06 - categorical_accuracy: 1.0000
# Epoch 262/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 2.9170e-06 - categorical_accuracy: 1.0000
# Epoch 263/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 2.7950e-06 - categorical_accuracy: 1.0000
# Epoch 264/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 2.6884e-06 - categorical_accuracy: 1.0000
# Epoch 265/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.5734e-06 - categorical_accuracy: 1.0000
# Epoch 266/1000
# 3/3 [==============================] - 0s 79ms/step - loss: 2.4192e-06 - categorical_accuracy: 1.0000
# Epoch 267/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 2.3421e-06 - categorical_accuracy: 1.0000
# Epoch 268/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.2144e-06 - categorical_accuracy: 1.0000
# Epoch 269/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 2.1107e-06 - categorical_accuracy: 1.0000
# Epoch 270/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.9957e-06 - categorical_accuracy: 1.0000
# Epoch 271/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.8821e-06 - categorical_accuracy: 1.0000
# Epoch 272/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.7853e-06 - categorical_accuracy: 1.0000
# Epoch 273/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.7012e-06 - categorical_accuracy: 1.0000
# Epoch 274/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.5988e-06 - categorical_accuracy: 1.0000
# Epoch 275/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.5202e-06 - categorical_accuracy: 1.0000
# Epoch 276/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4347e-06 - categorical_accuracy: 1.0000
# Epoch 277/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.3674e-06 - categorical_accuracy: 1.0000
# Epoch 278/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.2860e-06 - categorical_accuracy: 1.0000
# Epoch 279/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.2075e-06 - categorical_accuracy: 1.0000
# Epoch 280/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 1.1191e-06 - categorical_accuracy: 1.0000
# Epoch 281/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.0532e-06 - categorical_accuracy: 1.0000
# Epoch 282/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 9.9714e-07 - categorical_accuracy: 1.0000
# Epoch 283/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 9.2561e-07 - categorical_accuracy: 1.0000
# Epoch 284/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 8.5269e-07 - categorical_accuracy: 1.0000
# Epoch 285/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 7.9238e-07 - categorical_accuracy: 1.0000
# Epoch 286/1000
# 3/3 [==============================] - 0s 79ms/step - loss: 7.2927e-07 - categorical_accuracy: 1.0000
# Epoch 287/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 6.7177e-07 - categorical_accuracy: 1.0000
# Epoch 288/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 6.2970e-07 - categorical_accuracy: 1.0000
# Epoch 289/1000
# 3/3 [==============================] - 0s 81ms/step - loss: 5.7360e-07 - categorical_accuracy: 1.0000
# Epoch 290/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 5.3293e-07 - categorical_accuracy: 1.0000
# Epoch 291/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 4.9927e-07 - categorical_accuracy: 1.0000
# Epoch 292/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 4.6421e-07 - categorical_accuracy: 1.0000
# Epoch 293/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 4.4738e-07 - categorical_accuracy: 1.0000
# Epoch 294/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 4.3196e-07 - categorical_accuracy: 1.0000
# Epoch 295/1000
# 3/3 [==============================] - 0s 122ms/step - loss: 4.0391e-07 - categorical_accuracy: 1.0000
# Epoch 296/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 3.8988e-07 - categorical_accuracy: 1.0000
# Epoch 297/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 3.6744e-07 - categorical_accuracy: 1.0000
# Epoch 298/1000
# 3/3 [==============================] - 0s 83ms/step - loss: 3.5482e-07 - categorical_accuracy: 1.0000
# Epoch 299/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 3.4360e-07 - categorical_accuracy: 1.0000
# Epoch 300/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 3.2817e-07 - categorical_accuracy: 1.0000
# Epoch 301/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 3.1415e-07 - categorical_accuracy: 1.0000
# Epoch 302/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 3.0013e-07 - categorical_accuracy: 1.0000
# Epoch 303/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 2.8610e-07 - categorical_accuracy: 1.0000
# Epoch 304/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 2.7488e-07 - categorical_accuracy: 1.0000
# Epoch 305/1000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.6366e-07 - categorical_accuracy: 1.0000
# Epoch 306/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 2.5244e-07 - categorical_accuracy: 1.0000
# Epoch 307/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 2.4122e-07 - categorical_accuracy: 1.0000
# Epoch 308/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 2.3421e-07 - categorical_accuracy: 1.0000
# Epoch 309/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 2.2439e-07 - categorical_accuracy: 1.0000
# Epoch 310/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.1458e-07 - categorical_accuracy: 1.0000
# Epoch 311/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 2.0616e-07 - categorical_accuracy: 1.0000
# Epoch 312/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.9915e-07 - categorical_accuracy: 1.0000
# Epoch 313/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.8793e-07 - categorical_accuracy: 1.0000
# Epoch 314/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.8372e-07 - categorical_accuracy: 1.0000
# Epoch 315/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.7531e-07 - categorical_accuracy: 1.0000
# Epoch 316/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 1.6830e-07 - categorical_accuracy: 1.0000
# Epoch 317/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.6409e-07 - categorical_accuracy: 1.0000
# Epoch 318/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 1.5567e-07 - categorical_accuracy: 1.0000
# Epoch 319/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.5006e-07 - categorical_accuracy: 1.0000
# Epoch 320/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.4726e-07 - categorical_accuracy: 1.0000
# Epoch 321/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.3884e-07 - categorical_accuracy: 1.0000
# Epoch 322/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.3604e-07 - categorical_accuracy: 1.0000
# Epoch 323/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.3043e-07 - categorical_accuracy: 1.0000
# Epoch 324/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.2482e-07 - categorical_accuracy: 1.0000
# Epoch 325/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000
# Epoch 326/1000
# 3/3 [==============================] - 0s 111ms/step - loss: 1.1640e-07 - categorical_accuracy: 1.0000
# Epoch 327/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.1360e-07 - categorical_accuracy: 1.0000
# Epoch 328/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.0939e-07 - categorical_accuracy: 1.0000
# Epoch 329/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 1.0518e-07 - categorical_accuracy: 1.0000
# Epoch 330/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 1.0098e-07 - categorical_accuracy: 1.0000
# Epoch 331/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 9.6770e-08 - categorical_accuracy: 1.0000
# Epoch 332/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 9.5367e-08 - categorical_accuracy: 1.0000
# Epoch 333/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 9.1160e-08 - categorical_accuracy: 1.0000
# Epoch 334/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.8355e-08 - categorical_accuracy: 1.0000
# Epoch 335/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.5550e-08 - categorical_accuracy: 1.0000
# Epoch 336/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.4148e-08 - categorical_accuracy: 1.0000
# Epoch 337/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 7.9940e-08 - categorical_accuracy: 1.0000
# Epoch 338/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 7.8538e-08 - categorical_accuracy: 1.0000
# Epoch 339/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 7.5733e-08 - categorical_accuracy: 1.0000
# Epoch 340/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 7.4330e-08 - categorical_accuracy: 1.0000
# Epoch 341/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 7.1526e-08 - categorical_accuracy: 1.0000
# Epoch 342/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 7.1526e-08 - categorical_accuracy: 1.0000
# Epoch 343/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 7.0123e-08 - categorical_accuracy: 1.0000
# Epoch 344/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 6.7318e-08 - categorical_accuracy: 1.0000
# Epoch 345/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 6.4513e-08 - categorical_accuracy: 1.0000
# Epoch 346/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 6.3111e-08 - categorical_accuracy: 1.0000
# Epoch 347/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 6.1708e-08 - categorical_accuracy: 1.0000
# Epoch 348/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 5.8903e-08 - categorical_accuracy: 1.0000
# Epoch 349/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 5.6098e-08 - categorical_accuracy: 1.0000
# Epoch 350/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 5.4696e-08 - categorical_accuracy: 1.0000
# Epoch 351/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 5.3294e-08 - categorical_accuracy: 1.0000
# Epoch 352/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 5.3294e-08 - categorical_accuracy: 1.0000
# Epoch 353/1000
# 3/3 [==============================] - 0s 106ms/step - loss: 5.1891e-08 - categorical_accuracy: 1.0000
# Epoch 354/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 5.1891e-08 - categorical_accuracy: 1.0000
# Epoch 355/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 4.9086e-08 - categorical_accuracy: 1.0000
# Epoch 356/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 4.7684e-08 - categorical_accuracy: 1.0000
# Epoch 357/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 4.7684e-08 - categorical_accuracy: 1.0000
# Epoch 358/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 4.6281e-08 - categorical_accuracy: 1.0000
# Epoch 359/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 4.4879e-08 - categorical_accuracy: 1.0000
# Epoch 360/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 4.3476e-08 - categorical_accuracy: 1.0000
# Epoch 361/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 4.2074e-08 - categorical_accuracy: 1.0000
# Epoch 362/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 4.0671e-08 - categorical_accuracy: 1.0000
# Epoch 363/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 4.0671e-08 - categorical_accuracy: 1.0000
# Epoch 364/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 4.0671e-08 - categorical_accuracy: 1.0000
# Epoch 365/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 3.6464e-08 - categorical_accuracy: 1.0000
# Epoch 366/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 3.6464e-08 - categorical_accuracy: 1.0000
# Epoch 367/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 3.6464e-08 - categorical_accuracy: 1.0000
# Epoch 368/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 3.6464e-08 - categorical_accuracy: 1.0000
# Epoch 369/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 3.5062e-08 - categorical_accuracy: 1.0000
# Epoch 370/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 3.5062e-08 - categorical_accuracy: 1.0000
# Epoch 371/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 3.3659e-08 - categorical_accuracy: 1.0000
# Epoch 372/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 3.2257e-08 - categorical_accuracy: 1.0000
# Epoch 373/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 3.0854e-08 - categorical_accuracy: 1.0000
# Epoch 374/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 3.0854e-08 - categorical_accuracy: 1.0000
# Epoch 375/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 3.0854e-08 - categorical_accuracy: 1.0000
# Epoch 376/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.9452e-08 - categorical_accuracy: 1.0000
# Epoch 377/1000
# 3/3 [==============================] - 0s 79ms/step - loss: 2.8049e-08 - categorical_accuracy: 1.0000
# Epoch 378/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 2.9452e-08 - categorical_accuracy: 1.0000
# Epoch 379/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.9452e-08 - categorical_accuracy: 1.0000
# Epoch 380/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.9452e-08 - categorical_accuracy: 1.0000
# Epoch 381/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 2.6647e-08 - categorical_accuracy: 1.0000
# Epoch 382/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 2.6647e-08 - categorical_accuracy: 1.0000
# Epoch 383/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 2.5244e-08 - categorical_accuracy: 1.0000
# Epoch 384/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 2.5244e-08 - categorical_accuracy: 1.0000
# Epoch 385/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 2.5244e-08 - categorical_accuracy: 1.0000
# Epoch 386/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 2.5244e-08 - categorical_accuracy: 1.0000
# Epoch 387/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 2.5244e-08 - categorical_accuracy: 1.0000
# Epoch 388/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 2.3842e-08 - categorical_accuracy: 1.0000
# Epoch 389/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 2.3842e-08 - categorical_accuracy: 1.0000
# Epoch 390/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 2.3842e-08 - categorical_accuracy: 1.0000
# Epoch 391/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 392/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 393/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 394/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 395/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 396/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 397/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 398/1000
# 3/3 [==============================] - 0s 120ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 399/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 400/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 401/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.9634e-08 - categorical_accuracy: 1.0000
# Epoch 402/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.9634e-08 - categorical_accuracy: 1.0000
# Epoch 403/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.9634e-08 - categorical_accuracy: 1.0000
# Epoch 404/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.9634e-08 - categorical_accuracy: 1.0000
# Epoch 405/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.9634e-08 - categorical_accuracy: 1.0000
# Epoch 406/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.9634e-08 - categorical_accuracy: 1.0000
# Epoch 407/1000
# 3/3 [==============================] - 0s 81ms/step - loss: 1.8232e-08 - categorical_accuracy: 1.0000
# Epoch 408/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.8232e-08 - categorical_accuracy: 1.0000
# Epoch 409/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.6830e-08 - categorical_accuracy: 1.0000
# Epoch 410/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 411/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 412/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 413/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 414/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.4025e-08 - categorical_accuracy: 1.0000
# Epoch 415/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4025e-08 - categorical_accuracy: 1.0000
# Epoch 416/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 1.4025e-08 - categorical_accuracy: 1.0000
# ...
# Epoch 865/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 866/1000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 867/1000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 868/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 869/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 870/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 871/1000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 872/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 873/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 874/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 875/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 876/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 877/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 878/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 879/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 880/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 881/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 882/1000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 883/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 884/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 885/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 886/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 887/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 888/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 889/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 890/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 891/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 892/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 893/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 894/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 895/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 896/1000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 897/1000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 898/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 899/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 900/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 901/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 902/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 903/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 904/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 905/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 906/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 907/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 908/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 909/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 910/1000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 911/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 912/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 913/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 914/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 915/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 916/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 917/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 918/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 919/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 920/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 921/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 922/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 923/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 924/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 925/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 926/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 927/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 928/1000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 929/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 930/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 931/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 932/1000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 933/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 934/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 935/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 936/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 937/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 938/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 939/1000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 940/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 941/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 942/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 943/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 944/1000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 945/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 946/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 947/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 948/1000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 949/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 950/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 951/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 952/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 953/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 954/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 955/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 956/1000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 957/1000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 958/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 959/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 960/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 961/1000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 962/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 963/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 964/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 965/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 966/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 967/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 968/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 969/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 970/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 971/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 972/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 973/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 974/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 975/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 976/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 977/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 978/1000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 979/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 980/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 981/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 982/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 983/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 984/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 985/1000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 986/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 987/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 988/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 989/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 990/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 991/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 992/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 993/1000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 994/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 995/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 996/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 997/1000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 998/1000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 999/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1000/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20, 64)            48896
#
#  lstm_1 (LSTM)               (None, 20, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 203,459
# Trainable params: 203,459
# Non-trainable params: 0
# _________________________________________________________________

# %%
# How to run TensorBoard
# Using the command line
     # Navigate to the Logs/train folder
     # Run the following command:
          # tensorboard --logdir=.

# %% [markdown]
# # 8. Make Predictions

# %%
results = model.predict(X_test)
print(actions[np.argmax(results[1])])
print(actions[np.argmax(y_test[1])])
# Out:
# 1/1 [==============================] - 0s 32ms/step
# b
# b

# %% [markdown]
# # 9. Save, Delete, and Load Model

# %%
# Save Model
model.save('new_model.h5')

# %%
# Delete Model
del model

# %%
#Load Model
model.load_weights('new_model.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)  # Predicted values
ytrue = np.argmax(y_train, axis=1).tolist()  # Y true is the target values
yhat = np.argmax(yhat, axis=1).tolist()
# Out:
# 1/1 [==============================] - 0s 44ms/step

# %%
# Create Multilabel Confusion Matrix
# Top Row:    TP | FP
# Bottom Row: FN | TN
# You want numbers in the top left and bottom right

multilabel_confusion_matrix(ytrue, yhat)
# print(accuracy_score(ytrue, yhat))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16100\2830503505.py in <module>
#       4 # You want numbers in the top left and bottom right
#       5
# ----> 6 multilabel_confusion_matrix(ytrue, yhat)
#       7 # print(accuracy_score(ytrue, yhat))
#
# c:\Users\antho\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in multilabel_confusion_matrix(y_true, y_pred, sample_weight, labels, samplewise)
#     477             [1, 2]]])
#     478     """
# --> 479     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     480     if sample_weight is not None:
#     481         sample_weight = column_or_1d(sample_weight)
#
# c:\Users\antho\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# c:\Users\antho\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [85, 5]

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = [] # Stores 30 frames and once we do, pass it to the prediction algorithm
sentence = [] # Concatenates our predictions
predictions = []
threshold = 0.7 # Confidence Metric... needs to be this confident to consider it a letter

cap = cv2.VideoCapture(0)

# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
     while cap.isOpened():

          # Read feed
          ret, frame = cap.read()

          # Make detections
          image, results = mediapipe_detection(frame, holistic)
          print(results)
          
          # Draw landmarks
          draw_styled_landmarks(image, results)
          
          # 2. Prediction logic
          keypoints = extract_keypoints(results)
          sequence.append(keypoints)
          sequence = sequence[-30:]
          
          if len(sequence) == 30:
               res = model.predict(np.expand_dims(sequence, axis=0))[0] # Fixes the dimension from (30, 126) -> (1,30,126)
               print(actions[np.argmax(res)])
               predictions.append(np.argmax(res))
               
               
               #3. Viz logic
               if np.unique(predictions[-10:])[0]==np.argmax(res):
                    
                    # Checking if out result is above the threshold
                    if res[np.argmax(res)] > threshold: 
                         
                         if len(sentence) > 0:
                              # No repeat words in the sentence
                              if actions[np.argmax(res)] != sentence[-1]:
                                   sentence.append(actions[np.argmax(res)])
                         else: 
                              sentence.append(actions[np.argmax(res)])

               # Only keeping 5 values in a sentence. no need for this for the project
               if len(sentence) > 5: 
                    sentence = sentence[-5:]

               # Viz probabilities
               image = prob_viz(res, actions, image, colors)
               
          cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
          cv2.putText(image, ' '.join(sentence), (3,30), 
                         cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
          
          # Show to screen
          cv2.imshow('OpenCV Feed', image)

          # Break gracefully
          if cv2.waitKey(10) & 0xFF == ord('q'):
               break
     
     cap.release()
     cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# b
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# c
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# a
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# a
